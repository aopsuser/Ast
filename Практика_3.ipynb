# %% [markdown]
#  6 тапсырманың құрылымы мен қиындығы бірдей, бірақ тақырыптары мен мәндері әр студентке әртүрлі етіп жасалды.

# %% [markdown]
# ## Студент: Амангелді Мейірім
#
# **Деректер құрылымдары және JSON форматы**
#
# * **1-тапсырма: Тізімдер (Lists).** 5 түрлі жеміс атауынан тұратын тізім құрыңыз. Тізімге `append()` әдісі арқылы тағы 1 жеміс қосып, `remove()` немесе `pop()` арқылы бір элементті алып тастаңыз.
# * **2-тапсырма: Кортеждер (Tuples).** Кез келген 3 бүтін саннан тұратын кортеж құрыңыз. Кортеж элементтерін 3 түрлі айнымалыға тарқатыңыз (unpacking) және оларды экранға шығарыңыз.
# * **3-тапсырма: Сөздіктер (Dictionaries).** Кітап туралы ақпарат (атауы, авторы, шыққан жылы) бар сөздік құрыңыз. Сөздікке жаңадан кілт және мән қосыңыз.
# * **4-тапсырма: Жиындар (Sets).** Құрамында бірнеше ортақ сандары бар екі жиын (set) құрыңыз. Осы екі жиынның **қиылысуын** (intersection) табыңыз.
# * **5-тапсырма: Тізімдік өрнектер (List comprehension).** Тізімдік өрнекті қолданып, 1-ден 15-ке дейінгі сандардың ішінен тек **тақ сандардан** тұратын жаңа тізім жасаңыз.
# * **6-тапсырма: JSON форматы.** 3-тапсырмадағы немесе кез келген басқа сөздікті JSON форматындағы мәтінге (string) түрлендіріңіз. Содан кейін осы JSON мәтінін қайтадан Python сөздігіне айналдырыңыз.

# %%
import json

# --- 1-ТАПСЫРМА ---
# Жемістер тізімін құру және өзгертy
fruits = ["Алма", "Банан", "Апельсин", "Құлпынай", "Жүзім"]
print(fruits)
fruits.append("Алмұрт")
print("Жеміс қосқаннан кейін:", fruits)
fruits.remove("Банан")
print("Элементті өшіргеннен кейін:", fruits)

# --- 2-ТАПСЫРМА ---
# Кортежді құру және тарқату (unpacking)
numbers = (10, 20, 30)
a, b, c = numbers
print("a =", a)
print("b =", b)
print("c =", c)

# --- 3-ТАПСЫРМА ---
# Кітап туралы сөздікті құру және жаңа кілт қосу
book = {
    "title": "Абай жолы",
    "author": "Мұхтар Әуезов",
    "year": 1942
}
print("Бастапқы сөздік:", book)

book["genre"] = "Роман-эпопея"
print("Жаңартылған сөздік:", book)

# --- 4-ТАПСЫРМА ---
# Екі жиынды құру және қиылысуын табу
set1 = {1, 2, 3, 4, 5}
set2 = {4, 5, 6, 7, 8}
common_numbers = set1.intersection(set2)
print("Ортақ сандар (қиылысу):", common_numbers)

# --- 5-ТАПСЫРМА ---
# Тізімдік өрнек арқылы тақ сандар тізімін жасау
odd_numbers = [x for x in range(1, 16) if x % 2 != 0]
print("Тақ сандар тізімі:", odd_numbers)

# --- 6-ТАПСЫРМА ---
# Сөздікті JSON мәтініне түрлендіру және кері қайтару
import json
book = {
    "title": "Абай жолы",
    "author": "Мұхтар Әуезов",
    "year": 1942,
    "genre": "Роман-эпопея"
}
book_json = json.dumps(book, ensure_ascii=False, indent=4)
print("JSON форматындағы мәтін:\n", book_json)
print("Типі:", type(book_json))
book_dict = json.loads(book_json)
print("\nҚайтадан сөздікке айналған мәлімет:", book_dict)
print("Типі:", type(book_dict))
# Out:
# ['Алма', 'Банан', 'Апельсин', 'Құлпынай', 'Жүзім']
# Жеміс қосқаннан кейін: ['Алма', 'Банан', 'Апельсин', 'Құлпынай', 'Жүзім', 'Алмұрт']
# Элементті өшіргеннен кейін: ['Алма', 'Апельсин', 'Құлпынай', 'Жүзім', 'Алмұрт']
# a = 10
# b = 20
# c = 30
# Бастапқы сөздік: {'title': 'Абай жолы', 'author': 'Мұхтар Әуезов', 'year': 1942}
# Жаңартылған сөздік: {'title': 'Абай жолы', 'author': 'Мұхтар Әуезов', 'year': 1942, 'genre': 'Роман-эпопея'}
# Ортақ сандар (қиылысу): {4, 5}
# Тақ сандар тізімі: [1, 3, 5, 7, 9, 11, 13, 15]
# JSON форматындағы мәтін:
#  {
#     "title": "Абай жолы",
#     "author": "Мұхтар Әуезов",
#     "year": 1942,
#     "genre": "Роман-эпопея"
# }
# Типі: <class 'str'>
#
# Қайтадан сөздікке айналған мәлімет: {'title': 'Абай жолы', 'author': 'Мұхтар Әуезов', 'year': 1942, 'genre': 'Роман-эпопея'}
# Типі: <class 'dict'>

# %% [markdown]
# ## Студент: Ахат Аңсаған
#
# **Деректер құрылымдары және JSON форматы**
#
# * **1-тапсырма: Тізімдер (Lists).** 5 түрлі түс атауынан тұратын тізім құрыңыз. Тізімге `append()` әдісі арқылы тағы 1 түс қосып, `remove()` немесе `pop()` арқылы бір элементті алып тастаңыз.
# * **2-тапсырма: Кортеждер (Tuples).** 3 түрлі қала атауынан тұратын кортеж құрыңыз. Кортеж элементтерін 3 түрлі айнымалыға тарқатыңыз (unpacking) және оларды экранға шығарыңыз.
# * **3-тапсырма: Сөздіктер (Dictionaries).** Көлік туралы ақпарат (маркасы, моделі, шыққан жылы) бар сөздік құрыңыз. Сөздікке жаңадан кілт және мән қосыңыз.
# * **4-тапсырма: Жиындар (Sets).** Құрамында бірнеше ортақ сандары бар екі жиын (set) құрыңыз. Осы екі жиынның **бірігуін** (union) табыңыз.
# * **5-тапсырма: Тізімдік өрнектер (List comprehension).** Тізімдік өрнекті қолданып, 1-ден 10-ға дейінгі сандардың **квадраттарынан** тұратын жаңа тізім жасаңыз.
# * **6-тапсырма: JSON форматы.** 3-тапсырмадағы немесе кез келген басқа сөздікті JSON форматындағы мәтінге (string) түрлендіріңіз. Содан кейін осы JSON мәтінін қайтадан Python сөздігіне айналдырыңыз.

# %%
import json

# --- 1-ТАПСЫРМА ---
# Түстер тізімін құру және өзгерту
colors_list = []


# --- 2-ТАПСЫРМА ---
# Кортежді құру және тарқату (unpacking)
cities_tuple = ()


# --- 3-ТАПСЫРМА ---
# Көлік туралы сөздікті құру және жаңа кілт қосу
car_dict = {}


# --- 4-ТАПСЫРМА ---
# Екі жиынды құру және бірігуін табу
set_x = set()
set_y = set()


# --- 5-ТАПСЫРМА ---
# Тізімдік өрнек арқылы сандардың квадраттарын жасау
squared_numbers = []


# --- 6-ТАПСЫРМА ---
# Сөздікті JSON мәтініне түрлендіру және кері қайтару

# %% [markdown]
# ## Студент: Бахрам Бексұлтан
#
# **Деректер құрылымдары және JSON форматы**
#
# * **1-тапсырма: Тізімдер (Lists).** 5 түрлі оқу пәні атауынан тұратын тізім құрыңыз. Тізімге `append()` әдісі арқылы тағы 1 пән қосып, `remove()` немесе `pop()` арқылы бір элементті алып тастаңыз.
# * **2-тапсырма: Кортеждер (Tuples).** 3 бөлшек саннан (float) тұратын кортеж құрыңыз. Кортеж элементтерін 3 түрлі айнымалыға тарқатыңыз (unpacking) және оларды экранға шығарыңыз.
# * **3-тапсырма: Сөздіктер (Dictionaries).** Ноутбук туралы ақпарат (бренді, процессоры, жедел жады) бар сөздік құрыңыз. Сөздікке жаңадан кілт және мән қосыңыз.
# * **4-тапсырма: Жиындар (Sets).** Құрамында бірнеше ортақ сандары бар екі жиын (set) құрыңыз. Осы екі жиынның **айырмасын** (difference) табыңыз.
# * **5-тапсырма: Тізімдік өрнектер (List comprehension).** Тізімдік өрнекті қолданып, 1-ден 20-ға дейінгі сандардың ішінен тек **жұп сандардан** тұратын жаңа тізім жасаңыз.
# * **6-тапсырма: JSON форматы.** 3-тапсырмадағы немесе кез келген басқа сөздікті JSON форматындағы мәтінге (string) түрлендіріңіз. Содан кейін осы JSON мәтінін қайтадан Python сөздігіне айналдырыңыз.

# %%
import json

# --- 1-ТАПСЫРМА ---
# Пәндер тізімін құру және өзгерту
subjects_list = []


# --- 2-ТАПСЫРМА ---
# Кортежді құру және тарқату (unpacking)
floats_tuple = ()


# --- 3-ТАПСЫРМА ---
# Ноутбук туралы сөздікті құру және жаңа кілт қосу
laptop_dict = {}


# --- 4-ТАПСЫРМА ---
# Екі жиынды құру және айырмасын табу
set_one = set()
set_two = set()


# --- 5-ТАПСЫРМА ---
# Тізімдік өрнек арқылы жұп сандар тізімін жасау
even_numbers = []


# --- 6-ТАПСЫРМА ---
# Сөздікті JSON мәтініне түрлендіру және кері қайтару

# %% [markdown]
# ## Студент: Даирова Нұрсұлу Жарасқызы
#
# **Деректер құрылымдары және JSON форматы**
#
# * **1-тапсырма: Тізімдер (Lists).** 5 түрлі жануар атауынан тұратын тізім құрыңыз. Тізімге `append()` әдісі арқылы тағы 1 жануар қосып, `remove()` немесе `pop()` арқылы бір элементті алып тастаңыз.
# * **2-тапсырма: Кортеждер (Tuples).** 3 түрлі адам есімінен тұратын кортеж құрыңыз. Кортеж элементтерін 3 түрлі айнымалыға тарқатыңыз (unpacking) және оларды экранға шығарыңыз.
# * **3-тапсырма: Сөздіктер (Dictionaries).** Сүйікті фильміңіз туралы ақпарат (атауы, режиссері, рейтингі) бар сөздік құрыңыз. Сөздікке жаңадан кілт және мән қосыңыз.
# * **4-тапсырма: Жиындар (Sets).** Құрамында бірнеше ортақ сандары бар екі жиын (set) құрыңыз. Осы екі жиынның **қиылысуын** (intersection) табыңыз.
# * **5-тапсырма: Тізімдік өрнектер (List comprehension).** Тізімдік өрнекті қолданып, 1-ден 10-ға дейінгі сандардың **кубтарынан** тұратын жаңа тізім жасаңыз.
# * **6-тапсырма: JSON форматы.** 3-тапсырмадағы немесе кез келген басқа сөздікті JSON форматындағы мәтінге (string) түрлендіріңіз. Содан кейін осы JSON мәтінін қайтадан Python сөздігіне айналдырыңыз.

# %%
import json

# --- 1-ТАПСЫРМА ---
# Жануарлар тізімін құру және өзгерту
animals_list = []


# --- 2-ТАПСЫРМА ---
# Кортежді құру және тарқату (unpacking)
names_tuple = ()


# --- 3-ТАПСЫРМА ---
# Фильм туралы сөздікті құру және жаңа кілт қосу
movie_dict = {}


# --- 4-ТАПСЫРМА ---
# Екі жиынды құру және қиылысуын табу
group_a = set()
group_b = set()


# --- 5-ТАПСЫРМА ---
# Тізімдік өрнек арқылы сандардың кубтарын жасау
cubed_numbers = []


# --- 6-ТАПСЫРМА ---
# Сөздікті JSON мәтініне түрлендіру және кері қайтару

# %% [markdown]
# ## Студент: Жумадилов Дияр
#
# **Деректер құрылымдары және JSON форматы**
#
# * **1-тапсырма: Тізімдер (Lists).** 5 түрлі бағдарламалау тілінен тұратын тізім құрыңыз. Тізімге `append()` әдісі арқылы тағы 1 тіл қосып, `remove()` немесе `pop()` арқылы бір элементті алып тастаңыз.
# * **2-тапсырма: Кортеждер (Tuples).** 3 түрлі әріптен тұратын кортеж құрыңыз. Кортеж элементтерін 3 түрлі айнымалыға тарқатыңыз (unpacking) және оларды экранға шығарыңыз.
# * **3-тапсырма: Сөздіктер (Dictionaries).** Мемлекет туралы ақпарат (атауы, астанасы, халық саны) бар сөздік құрыңыз. Сөздікке жаңадан кілт және мән қосыңыз.
# * **4-тапсырма: Жиындар (Sets).** Құрамында бірнеше ортақ сандары бар екі жиын (set) құрыңыз. Осы екі жиынның **бірігуін** (union) табыңыз.
# * **5-тапсырма: Тізімдік өрнектер (List comprehension).** Тізімдік өрнекті қолданып, 1-ден 30-ға дейінгі сандардың ішінен **3-ке қалдықсыз бөлінетін** сандардан тұратын жаңа тізім жасаңыз.
# * **6-тапсырма: JSON форматы.** 3-тапсырмадағы немесе кез келген басқа сөздікті JSON форматындағы мәтінге (string) түрлендіріңіз. Содан кейін осы JSON мәтінін қайтадан Python сөздігіне айналдырыңыз.

# %%
import json

# --- 1-ТАПСЫРМА ---
# Бағдарламалау тілдері тізімін құру және өзгерту
languages_list = []


# --- 2-ТАПСЫРМА ---
# Кортежді құру және тарқату (unpacking)
letters_tuple = ()


# --- 3-ТАПСЫРМА ---
# Мемлекет туралы сөздікті құру және жаңа кілт қосу
country_dict = {}


# --- 4-ТАПСЫРМА ---
# Екі жиынды құру және бірігуін табу
set_alpha = set()
set_beta = set()


# --- 5-ТАПСЫРМА ---
# Тізімдік өрнек арқылы 3-ке бөлінетін сандар тізімін жасау
divisible_by_three = []


# --- 6-ТАПСЫРМА ---
# Сөздікті JSON мәтініне түрлендіру және кері қайтару

# %% [markdown]
# ## Студент: Жүнісова Әсел
# **Деректер құрылымдары және JSON форматы**
#
# * **1-тапсырма: Тізімдер (Lists).** 5 түрлі мамандық атауынан тұратын тізім құрыңыз. Тізімге `append()` әдісі арқылы тағы 1 мамандық қосып, `remove()` немесе `pop()` арқылы бір элементті алып тастаңыз.
# * **2-тапсырма: Кортеждер (Tuples).** 3 түрлі емтихан бағасынан тұратын кортеж құрыңыз. Кортеж элементтерін 3 түрлі айнымалыға тарқатыңыз (unpacking) және оларды экранға шығарыңыз.
# * **3-тапсырма: Сөздіктер (Dictionaries).** Қала туралы ақпарат (атауы, орналасқан аймағы, ауданы) бар сөздік құрыңыз. Сөздікке жаңадан кілт және мән қосыңыз.
# * **4-тапсырма: Жиындар (Sets).** Құрамында бірнеше ортақ сандары бар екі жиын (set) құрыңыз. Осы екі жиынның **айырмасын** (difference) табыңыз.
# * **5-тапсырма: Тізімдік өрнектер (List comprehension).** Тізімдік өрнекті қолданып, **10-нан 20-ға дейінгі** сандардың квадраттарынан тұратын жаңа тізім жасаңыз.
# * **6-тапсырма: JSON форматы.** 3-тапсырмадағы немесе кез келген басқа сөздікті JSON форматындағы мәтінге (string) түрлендіріңіз. Содан кейін осы JSON мәтінін қайтадан Python сөздігіне айналдырыңыз.

# %%
import json

# --- 1-ТАПСЫРМА ---
# Мамандықтар тізімін құру және өзгерту
professions_list = []


# --- 2-ТАПСЫРМА ---
# Кортежді құру және тарқату (unpacking)
grades_tuple = ()


# --- 3-ТАПСЫРМА ---
# Қала туралы сөздікті құру және жаңа кілт қосу
city_dict = {}


# --- 4-ТАПСЫРМА ---
# Екі жиынды құру және айырмасын табу
set_c = set()
set_d = set()


# --- 5-ТАПСЫРМА ---
# Тізімдік өрнек арқылы 10-20 сандардың квадраттарын жасау
squares_10_to_20 = []


# --- 6-ТАПСЫРМА ---
# Сөздікті JSON мәтініне түрлендіру және кері қайтару

# %% [markdown]
# ## Студент: Кинаятов Наурызбай
#
# **Деректер құрылымдары және JSON форматы**
#
# * **1-тапсырма: Тізімдер (Lists).** 5 түрлі ІТ-компания атауынан тұратын тізім құрыңыз. Тізімге `append()` әдісі арқылы тағы 1 компания қосып, `remove()` немесе `pop()` арқылы бір элементті алып тастаңыз.
# * **2-тапсырма: Кортеждер (Tuples).** Заттың 3 өлшемінен (ұзындығы, ені, биіктігі) тұратын кортеж құрыңыз. Кортеж элементтерін 3 түрлі айнымалыға тарқатыңыз (unpacking) және оларды экранға шығарыңыз.
# * **3-тапсырма: Сөздіктер (Dictionaries).** Смартфон туралы ақпарат (маркасы, жады көлемі, камерасы) бар сөздік құрыңыз. Сөздікке жаңадан кілт және мән қосыңыз.
# * **4-тапсырма: Жиындар (Sets).** Құрамында бірнеше ортақ сандары бар екі жиын (set) құрыңыз. Осы екі жиынның **қиылысуын** (intersection) табыңыз.
# * **5-тапсырма: Тізімдік өрнектер (List comprehension).** Тізімдік өрнекті қолданып, 1-ден 15-ке дейінгі сандардың ішінен тек **жұп сандардан** тұратын жаңа тізім жасаңыз.
# * **6-тапсырма: JSON форматы.** 3-тапсырмадағы немесе кез келген басқа сөздікті JSON форматындағы мәтінге (string) түрлендіріңіз. Содан кейін осы JSON мәтінін қайтадан Python сөздігіне айналдырыңыз.

# %%
import json

# --- 1-ТАПСЫРМА ---
# Компаниялар тізімін құру және өзгерту
companies_list = []


# --- 2-ТАПСЫРМА ---
# Кортежді құру және тарқату (unpacking)
dimensions_tuple = ()


# --- 3-ТАПСЫРМА ---
# Смартфон туралы сөздікті құру және жаңа кілт қосу
phone_dict = {}


# --- 4-ТАПСЫРМА ---
# Екі жиынды құру және қиылысуын табу
set_m = set()
set_n = set()


# --- 5-ТАПСЫРМА ---
# Тізімдік өрнек арқылы жұп сандар тізімін жасау
even_numbers = []


# --- 6-ТАПСЫРМА ---
# Сөздікті JSON мәтініне түрлендіру және кері қайтару

# %% [markdown]
# ## Студент: Манапалы Жанерке
#
# **Деректер құрылымдары және JSON форматы**
#
# * **1-тапсырма: Тізімдер (Lists).** 5 түрлі компьютерлік ойын атауынан тұратын тізім құрыңыз. Тізімге `append()` әдісі арқылы тағы 1 ойын қосып, `remove()` немесе `pop()` арқылы бір элементті алып тастаңыз.
# * **2-тапсырма: Кортеждер (Tuples).** 3 түрлі құрылғы атауынан (мысалы, тінтуір, пернетақта) тұратын кортеж құрыңыз. Кортеж элементтерін 3 түрлі айнымалыға тарқатыңыз (unpacking) және оларды экранға шығарыңыз.
# * **3-тапсырма: Сөздіктер (Dictionaries).** Қызметкер туралы ақпарат (аты-жөні, лауазымы, жалақысы) бар сөздік құрыңыз. Сөздікке жаңадан кілт және мән қосыңыз.
# * **4-тапсырма: Жиындар (Sets).** Құрамында бірнеше ортақ сандары бар екі жиын (set) құрыңыз. Осы екі жиынның **бірігуін** (union) табыңыз.
# * **5-тапсырма: Тізімдік өрнектер (List comprehension).** Тізімдік өрнекті қолданып, 1-ден 20-ға дейінгі сандардың ішінен **тек тақ сандардың квадраттарынан** тұратын жаңа тізім жасаңыз.
# * **6-тапсырма: JSON форматы.** 3-тапсырмадағы немесе кез келген басқа сөздікті JSON форматындағы мәтінге (string) түрлендіріңіз. Содан кейін осы JSON мәтінін қайтадан Python сөздігіне айналдырыңыз.

# %%
import json

# --- 1-ТАПСЫРМА ---
# Ойындар тізімін құру және өзгерту
games_list = []


# --- 2-ТАПСЫРМА ---
# Кортежді құру және тарқату (unpacking)
devices_tuple = ()


# --- 3-ТАПСЫРМА ---
# Қызметкер туралы сөздікті құру және жаңа кілт қосу
employee_dict = {}


# --- 4-ТАПСЫРМА ---
# Екі жиынды құру және бірігуін табу
set_q = set()
set_w = set()


# --- 5-ТАПСЫРМА ---
# Тізімдік өрнек арқылы тақ сандардың квадраттарын жасау
odd_squares = []


# --- 6-ТАПСЫРМА ---
# Сөздікті JSON мәтініне түрлендіру және кері қайтару

# %% [markdown]
# ## Студент: Саматқызы Амина
#
# **Деректер құрылымдары және JSON форматы**
#
# * **1-тапсырма: Тізімдер (Lists).** 5 түрлі тағам атауынан тұратын тізім құрыңыз. Тізімге `append()` әдісі арқылы тағы 1 тағам қосып, `remove()` немесе `pop()` арқылы бір элементті алып тастаңыз.
# * **2-тапсырма: Кортеждер (Tuples).** Жылдың 3 айының атауынан тұратын кортеж құрыңыз. Кортеж элементтерін 3 түрлі айнымалыға тарқатыңыз (unpacking) және оларды экранға шығарыңыз.
# * **3-тапсырма: Сөздіктер (Dictionaries).** Университет туралы ақпарат (атауы, факультеттер саны, студенттер саны) бар сөздік құрыңыз. Сөздікке жаңадан кілт және мән қосыңыз.
# * **4-тапсырма: Жиындар (Sets).** Құрамында бірнеше ортақ сандары бар екі жиын (set) құрыңыз. Осы екі жиынның **айырмасын** (difference) табыңыз.
# * **5-тапсырма: Тізімдік өрнектер (List comprehension).** Тізімдік өрнекті қолданып, 1-ден 10-ға дейінгі сандардың **кубтарынан** тұратын жаңа тізім жасаңыз.
# * **6-тапсырма: JSON форматы.** 3-тапсырмадағы немесе кез келген басқа сөздікті JSON форматындағы мәтінге (string) түрлендіріңіз. Содан кейін осы JSON мәтінін қайтадан Python сөздігіне айналдырыңыз.

# %%
import json

# --- 1-ТАПСЫРМА ---
# Тағамдар тізімін құру және өзгерту
foods_list = []


# --- 2-ТАПСЫРМА ---
# Кортежді құру және тарқату (unpacking)
months_tuple = ()


# --- 3-ТАПСЫРМА ---
# Университет туралы сөздікті құру және жаңа кілт қосу
university_dict = {}


# --- 4-ТАПСЫРМА ---
# Екі жиынды құру және айырмасын табу
set_first = set()
set_second = set()


# --- 5-ТАПСЫРМА ---
# Тізімдік өрнек арқылы сандардың кубтарын жасау
cubed_numbers = []


# --- 6-ТАПСЫРМА ---
# Сөздікті JSON мәтініне түрлендіру және кері қайтару
